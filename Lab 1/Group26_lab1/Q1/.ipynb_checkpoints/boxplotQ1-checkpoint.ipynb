# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import copy
import pandas as pd
from pandas import DataFrame
import seaborn as sns

# %%
def dataprocess(old_data):
    new_data = copy.deepcopy(old_data)
    for k in range(len(new_data)):   
        for i in range(len(new_data[k])):
            if new_data[k][i] > 2*(np.mean(old_data[k])):
                new_data[k][i] = np.median(new_data[k])
    return new_data

# %%
num = '0';
names = ['256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1M', '2M', '4M']
rawdata = []

# %%
# Store all the data from the transport time
# with non-real propotities and no extra load on CPU
for i in range(len(names)):
    filename = "transport_time/transport_time_" + names[i] + "byte.txt"
    a = np.loadtxt(filename)
    rawdata.append(a)

# %%
print(len(rawdata))
print(rawdata[0][0])
# Out:
# 15
# 0.020479202

# %%
plt.figure(figsize=(10,5))#设置画布的尺寸
plt.title('Boxplot of transport time in different data size',fontsize=20)#标题，并设定字号大小
labels = ['x1','x2']#图例
plt.boxplot(rawdata, labels = ['256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1M', '2M', '4M'])#grid=False：代表不显示背景中的网格线
# data.boxplot()#画箱型图的另一种方法，参数较少，而且只接受dataframe，不常用
plt.savefig('test data raw'+ num + '.jpg')
plt.show()#显示图像

# %%
newdata = dataprocess(rawdata)

# %%
print(len(rawdata))
print(rawdata[0][0])
# Out:
# 15
# 0.011000872

# %%
plt.plot(rawdata[0])
plt.plot(newdata[0])
plt.legend(('original', 'new'), loc='upper right')  
plt.title('transport time 1Mbyte')  
plt.savefig('test data fixed and raw compared 256'+ num + '.jpg')
plt.show()

# %%
plt.figure(figsize=(10,5))#设置画布的尺寸
plt.title('Boxplot of transport time in different data size',fontsize=20)#标题，并设定字号大小
labels = ['x1','x2']#图例
plt.boxplot(newdata, labels = ['256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1M', '2M', '4M'])#grid=False：代表不显示背景中的网格线
# data.boxplot()#画箱型图的另一种方法，参数较少，而且只接受dataframe，不常用
plt.savefig('test data new'+ num + '.jpg')
plt.show()#显示图像
